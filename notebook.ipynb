# %%
stock = {
"pains au chocolat": 500,
"croissants": 400,
"baguettes": 500,
"beignets": 200
}

# %%
def afficher_inventaire(stock):
    print("Inventaire de la boulangerie :")
    for produit, quantite in stock.items():
        print(f"{produit} : {quantite}")
afficher_inventaire(stock)
# Out:
# Inventaire de la boulangerie :
# pains au chocolat : 500
# croissants : 500
# baguettes : 500
# beignets : 200
